# %%
# MACOS RSSI sampler
# WINGS.BangyaLiu

import subprocess
import json
import time

CMD = "/System/Library/PrivateFrameworks/Apple80211.framework/Versions/Current/Resources/airport"
ROUTE_MODE = True

def get_fp_triad_list():
    scan_cmd = subprocess.Popen([CMD, '-s'], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    scan_out, scan_err = scan_cmd.communicate()
    scan_out_lines = str(scan_out).split("\\n")[1:-1]
    triad_list = []
    for l in scan_out_lines:
        name = l[:32].strip()
        mac = l[33:50]
        rssi = int(l[51:55])
        triad_list.append([name, mac, rssi])
    triad_list.sort(key = lambda x: x[0])
    return triad_list

def json_package(locId):
    """
        file name: sectionId_devName.json 
        NOTICE: It should be a JSON LIST but for the convenience of incremental record, brackets are eliminated.
        {
            "location" : string,
            "timestamp" : timestamp,
            "counter" : integer,
            "fingerprint" : [[Triad], [Triad], ... , [Triad]],
        } * N lines
    """
    readingAP = get_fp_triad_list()
    one_record = {
        "location" : locId,
        "timestamp" : int(time.time()),
        "counter" : len(readingAP),
        "fingerprint" : readingAP
    }
    return json.dumps(one_record)

def main():
    devName = input("what is your device : ").replace(" ", "")
    secId = input("which section you are at : ").replace(" ", "")
    fileName = devName + "_" + str(secId) + ".json"
    locId = input("what is your current location : ")
    while locId:
        with open(fileName, "a+") as f:
            f.write(json_package(locId) + "\n")
        locId = input("what is your current location : ")

def route_mode():
    devName = input("what is your device : ").replace(" ", "")
    secId = input("which section you are at : ").replace(" ", "")
    fileName = devName + "_" + str(secId) + ".json"
    interval = int(input("route mode interval (s) : "))
    totalCtr = int(input("total samples to gather : "))
    for locId in range(totalCtr):
        print("[route mode] start collecting sample#{}.".format(locId))
        with open(fileName, "a+") as f:
            f.write(json_package(str(locId)) + "\n")
        print("[route mode] sample#{} has been collected, go to the next spot with in {} seconds.".format(locId, interval))
        time.sleep(interval)

if ROUTE_MODE:
    route_mode()
else:
    main()
# Out:
# [route mode] start collecting sample#0.
# [route mode] sample#0 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#1.
# [route mode] sample#1 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#2.
# [route mode] sample#2 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#3.
# [route mode] sample#3 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#4.
# [route mode] sample#4 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#5.
# [route mode] sample#5 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#6.
# [route mode] sample#6 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#7.
# [route mode] sample#7 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#8.
# [route mode] sample#8 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#9.
# [route mode] sample#9 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#10.
# [route mode] sample#10 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#11.
# [route mode] sample#11 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#12.
# [route mode] sample#12 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#13.
# [route mode] sample#13 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#14.
# [route mode] sample#14 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#15.
# [route mode] sample#15 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#16.
# [route mode] sample#16 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#17.
# [route mode] sample#17 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#18.
# [route mode] sample#18 has been collected, go to the next spot with in 2 seconds.
# [route mode] start collecting sample#19.
# [route mode] sample#19 has been collected, go to the next spot with in 2 seconds.
